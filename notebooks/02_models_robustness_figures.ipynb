# %% [markdown]
# <a href="https://colab.research.google.com/github/apropos0/Scheduling_Inference/blob/master/notebooks/02_models_robustness_figures.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# <a href="https://colab.research.google.com/github/apropos0/Scheduling_Inference/blob/main/notebooks/02_models_robustness_figures.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>
#
# # 02 — Models + Robustness + Figures
#
# Loads processed features if present; otherwise rebuilds from raw CSV (load-or-build).

# %%
# !rm -rf Scheduling_Inference
# !git clone https://github.com/apropos0/Scheduling_Inference.git
# Out:
# Cloning into 'Scheduling_Inference'...
# remote: Enumerating objects: 47, done.
# remote: Counting objects: 100% (47/47), done.
# remote: Compressing objects: 100% (39/39), done.
# remote: Total 47 (delta 7), reused 38 (delta 5), pack-reused 0 (from 0)
# Receiving objects: 100% (47/47), 52.50 KiB | 790.00 KiB/s, done.
# Resolving deltas: 100% (7/7), done.

# %%
SESSION_ID = "2025-12-31_A"

# %%
import sys
sys.path.append("Scheduling_Inference")

from pathlib import Path
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from sklearn.model_selection import train_test_split, StratifiedKFold, cross_val_score
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import classification_report, confusion_matrix, ConfusionMatrixDisplay

from src.paths import raw_csv, clean_parquet
from src.features import add_features

# %%
p = clean_parquet(SESSION_ID)

if p.exists():
    df = pd.read_parquet(p)
    print("Loaded processed:", p, "shape:", df.shape)
else:
    rp = raw_csv(SESSION_ID)
    if not rp.exists():
        raise FileNotFoundError(
            f"Missing raw CSV: {rp}\n"
            f"Expected: Scheduling_Inference/data/raw/results_{SESSION_ID}.csv"
        )
    raw = pd.read_csv(rp)
    df = add_features(raw)
    p.parent.mkdir(parents=True, exist_ok=True)
    df.to_parquet(p, index=False)
    print("Built + wrote processed:", p, "shape:", df.shape)

df.head()
# Out:
# Loaded processed: /content/Scheduling_Inference/data/processed/clean_2025-12-31_A.parquet shape: (270, 19)
#     timestamp    session_id policy workload  task_clock  context_switches  \
# 0  1767218075  2025-12-31_A    cfs     burn    10018.92               317
# 1  1767218085  2025-12-31_A    cfs     burn    10014.52               268
# 2  1767218095  2025-12-31_A    cfs     burn    10014.06               265
# 3  1767218105  2025-12-31_A    cfs     burn    10014.13               312
# 4  1767218115  2025-12-31_A    cfs     burn    10014.12               297
#
#    cpu_migrations       cycles  instructions     branches  branch_misses  \
# 0               1  23994470976   67179454061  11076280054         586260
# 1               1  24033712526   67212372306  11081679721         574174
# 2               0  24032602895   67014279639  11049027703         566662
# 3               1  24032617822   65862109547  10859169186         575540
# 4               0  24032649962   67289163045  11094423345         571224
#
#    task_sec  cs_per_sec  mig_per_sec  cycles_per_sec  instr_per_sec  \
# 0  10.01892   31.640137     0.099811    2.394916e+09   6.705259e+09
# 1  10.01452   26.761143     0.099855    2.399887e+09   6.711492e+09
# 2  10.01406   26.462793     0.000000    2.399886e+09   6.692019e+09
# 3  10.01413   31.155977     0.099859    2.399871e+09   6.576918e+09
# 4  10.01412   29.658123     0.000000    2.399876e+09   6.719428e+09
#
#    branches_per_sec       ipc  branch_miss_rate
# 0      1.105536e+09  2.799789          0.000053
# 1      1.106561e+09  2.796587          0.000052
# 2      1.103351e+09  2.788474          0.000051
# 3      1.084385e+09  2.740530          0.000053
# 4      1.107878e+09  2.799906          0.000051

# %%
features = [
    "cs_per_sec",
    "mig_per_sec",
    "cycles_per_sec",
    "instr_per_sec",
    "branches_per_sec",
    "ipc",
    "branch_miss_rate",
]

model_df = df.dropna(subset=features + ["policy"]).copy()
X = model_df[features]
y = model_df["policy"]

print("Rows:", model_df.shape[0])
print("Class balance:\n", y.value_counts())
# Out:
# Rows: 270
# Class balance:
#  policy
# cfs     90
# rr      90
# fifo    90
# Name: count, dtype: int64

# %%
X_train, X_test, y_train, y_test = train_test_split(
    X, y,
    test_size=0.25,
    random_state=42,
    stratify=y,
)

logreg = Pipeline([
    ("scaler", StandardScaler()),
    ("clf", LogisticRegression(max_iter=2000)),
])

logreg.fit(X_train, y_train)
pred = logreg.predict(X_test)

print("LogReg (holdout)")
print(classification_report(y_test, pred))

cm = confusion_matrix(y_test, pred, labels=logreg.named_steps["clf"].classes_)
ConfusionMatrixDisplay(cm, display_labels=logreg.named_steps["clf"].classes_).plot()
plt.title("Confusion matrix (LogReg holdout)")
plt.show()
# Out:
# LogReg (holdout)
#               precision    recall  f1-score   support
#
#          cfs       0.62      0.82      0.71        22
#         fifo       0.39      0.30      0.34        23
#           rr       0.48      0.43      0.45        23
#
#     accuracy                           0.51        68
#    macro avg       0.50      0.52      0.50        68
# weighted avg       0.49      0.51      0.50        68

# %%
rf = RandomForestClassifier(n_estimators=300, random_state=42)
rf.fit(X_train, y_train)
pred_rf = rf.predict(X_test)

print("RandomForest (holdout)")
print(classification_report(y_test, pred_rf))

cm = confusion_matrix(y_test, pred_rf, labels=rf.classes_)
ConfusionMatrixDisplay(cm, display_labels=rf.classes_).plot()
plt.title("Confusion matrix (RF holdout)")
plt.show()
# Out:
# RandomForest (holdout)
#               precision    recall  f1-score   support
#
#          cfs       0.96      1.00      0.98        22
#         fifo       0.58      0.65      0.61        23
#           rr       0.58      0.48      0.52        23
#
#     accuracy                           0.71        68
#    macro avg       0.70      0.71      0.70        68
# weighted avg       0.70      0.71      0.70        68

# %%
cv = StratifiedKFold(n_splits=5, shuffle=True, random_state=42)
scores_lr = cross_val_score(logreg, X, y, cv=cv, scoring="accuracy")
scores_rf = cross_val_score(rf, X, y, cv=cv, scoring="accuracy")

print("LogReg CV acc:", float(scores_lr.mean()), "+/-", float(scores_lr.std()))
print("RF CV acc:", float(scores_rf.mean()), "+/-", float(scores_rf.std()))
# Out:
# LogReg CV acc: 0.5333333333333333 +/- 0.05785370130301225
# RF CV acc: 0.7 +/- 0.051586623248830066

# %%
clf = logreg.named_steps["clf"]
coef_df = pd.DataFrame(clf.coef_, columns=features, index=clf.classes_)
coef_df
# Out:
#       cs_per_sec  mig_per_sec  cycles_per_sec  instr_per_sec  \
# cfs     0.291981    -1.371392       -0.420632       0.187818
# fifo   -0.002869     0.712585        0.231687       0.009949
# rr     -0.289112     0.658808        0.188944      -0.197767
#
#       branches_per_sec       ipc  branch_miss_rate
# cfs          -0.031146  0.260172         -0.735725
# fifo         -0.086518 -0.036203          0.474472
# rr            0.117665 -0.223968          0.261254

# %%
imp = pd.Series(rf.feature_importances_, index=features).sort_values(ascending=False)
imp
# Out:
# branch_miss_rate    0.261060
# mig_per_sec         0.211766
# cs_per_sec          0.143671
# cycles_per_sec      0.107605
# ipc                 0.092854
# branches_per_sec    0.091922
# instr_per_sec       0.091121
# dtype: float64
